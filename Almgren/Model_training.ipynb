# %% [markdown]
# # Deep Reinforcement Learning for Optimal Execution of Portfolio Transactions

# %%
import utils

# Get the default financial and AC Model parameters
financial_params, ac_params = utils.get_env_param()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-33bbab84cdb5> in <module>
# ----> 1 import utils
#       2
#       3 # Get the default financial and AC Model parameters
#       4 financial_params, ac_params = utils.get_env_param()
#
# c:\Users\anas1\Downloads\Multi-Agent-RL-for-Liquidation-master\Multi-Agent-RL-for-Liquidation-master\utils.py in <module>
#       7
#       8 from statsmodels.iolib.table import SimpleTable
# ----> 9 from statsmodels.compat.python import zip_longest
#      10 from statsmodels.iolib.tableformatting import fmt_2cols
#      11
#
# ImportError: cannot import name 'zip_longest' from 'statsmodels.compat.python' (C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\compat\python.py)

# %%
# !pip3 install --upgrade git+https://github.com/mfschmidt/PyGEST.git
# Out:
# Collecting git+https://github.com/mfschmidt/PyGEST.git
#   Cloning https://github.com/mfschmidt/PyGEST.git to c:\users\anas1\appdata\local\temp\pip-req-build-qp3e_4f1
# Requirement already satisfied: pandas in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (1.2.2)
# Requirement already satisfied: numpy in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (1.22.2)
# Requirement already satisfied: scipy in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (1.8.0)
# Requirement already satisfied: statsmodels in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (0.13.2)
# Collecting humanize
#   Downloading humanize-4.0.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: requests in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (2.26.0)
# Requirement already satisfied: matplotlib in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (3.5.1)
# Requirement already satisfied: seaborn in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pygest==1.2.2) (0.11.1)
# Collecting reportlab
#   Downloading reportlab-3.6.7-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting nipype
#   Downloading nipype-1.7.0-py3-none-any.whl (3.2 MB)
#   Running command git clone -q https://github.com/mfschmidt/PyGEST.git 'C:\Users\anas1\AppData\Local\Temp\pip-req-build-qp3e_4f1'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\anas1\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\anas1\\AppData\\Local\\Temp\\pip-req-build-qp3e_4f1\\setup.py'"'"'; __file__='"'"'C:\\Users\\anas1\\AppData\\Local\\Temp\\pip-req-build-qp3e_4f1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\anas1\AppData\Local\Temp\pip-wheel-cpptzx56'
#        cwd: C:\Users\anas1\AppData\Local\Temp\pip-req-build-qp3e_4f1\
#   Complete output (59 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\pygest
#   copying pygest\algorithms.py -> build\lib\pygest
#   copying pygest\convenience.py -> build\lib\pygest
#   copying pygest\data.py -> build\lib\pygest
#   copying pygest\erminej.py -> build\lib\pygest
#   copying pygest\plot.py -> build\lib\pygest
#   copying pygest\reporting.py -> build\lib\pygest
#   copying pygest\storage.py -> build\lib\pygest
#   copying pygest\workers.py -> build\lib\pygest
#   copying pygest\__init__.py -> build\lib\pygest
# Collecting boto3
#   Downloading boto3-1.21.3-py3-none-any.whl (132 kB)
# Collecting botocore
#   Downloading botocore-1.24.3-py3-none-any.whl (8.5 MB)
# Collecting brainsmash
#   Downloading brainsmash-0.11.0-py3-none-any.whl (268 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.1-py3-none-any.whl (79 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\anas1\appdata\roaming\python\python39\site-packages (from botocore->pygest==1.2.2) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from botocore->pygest==1.2.2) (1.26.7)
# Requirement already satisfied: six>=1.5 in c:\users\anas1\appdata\roaming\python\python39\site-packages (from python-dateutil<3.0.0,>=2.1->botocore->pygest==1.2.2) (1.15.0)
# Requirement already satisfied: joblib in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from brainsmash->pygest==1.2.2) (1.0.1)
# Collecting nibabel
#   Downloading nibabel-3.2.2-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: scikit-learn in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from brainsmash->pygest==1.2.2) (0.24.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->pygest==1.2.2) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->pygest==1.2.2) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->pygest==1.2.2) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->pygest==1.2.2) (8.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->pygest==1.2.2) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->pygest==1.2.2) (4.29.1)
# Requirement already satisfied: setuptools in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from nibabel->brainsmash->pygest==1.2.2) (60.7.1)
# Requirement already satisfied: click>=6.6.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from nipype->pygest==1.2.2) (8.0.3)
# Requirement already satisfied: networkx>=2.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from nipype->pygest==1.2.2) (2.5)
# Collecting prov>=1.5.2
#   Downloading prov-2.0.0-py3-none-any.whl (421 kB)
# Requirement already satisfied: pydot>=1.2.3 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from nipype->pygest==1.2.2) (1.4.2)
# Collecting simplejson>=3.8.0
#   Downloading simplejson-3.17.6-cp39-cp39-win_amd64.whl (75 kB)
# Collecting rdflib>=5.0.0
#   Using cached rdflib-6.1.1-py3-none-any.whl (482 kB)
# Collecting filelock>=3.0.0
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Collecting traits!=5.0,>=4.6
#   Downloading traits-6.3.2-cp39-cp39-win_amd64.whl (5.0 MB)
# Collecting etelemetry>=0.2.0
#   Downloading etelemetry-0.3.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: colorama in c:\users\anas1\appdata\roaming\python\python39\site-packages (from click>=6.6.0->nipype->pygest==1.2.2) (0.4.4)
# Collecting ci-info>=0.2
#   Downloading ci_info-0.2.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\anas1\appdata\roaming\python\python39\site-packages (from networkx>=2.0->nipype->pygest==1.2.2) (4.4.2)
# Collecting lxml>=3.3.5
#   Downloading lxml-4.8.0-cp39-cp39-win_amd64.whl (3.6 MB)
# Collecting isodate
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from pandas->pygest==1.2.2) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from requests->pygest==1.2.2) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from requests->pygest==1.2.2) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from requests->pygest==1.2.2) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->brainsmash->pygest==1.2.2) (2.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\anas1\appdata\local\programs\python\python39\lib\site-packages (from statsmodels->pygest==1.2.2) (0.5.2)
# Building wheels for collected packages: pygest
#   Building wheel for pygest (setup.py): started
#   Building wheel for pygest (setup.py): finished with status 'error'
#   Running setup.py clean for pygest
# Failed to build pygest
# Installing collected packages: jmespath, isodate, rdflib, lxml, ci-info, botocore, traits, simplejson, s3transfer, prov, nibabel, filelock, etelemetry, reportlab, nipype, humanize, brainsmash, boto3, pygest
#     Running setup.py install for pygest: started
#     Running setup.py install for pygest: finished with status 'error'
#   creating build\lib\pygest\cmdline
#   copying pygest\cmdline\command.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\commands.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\csv2df.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\ktau.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\move.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\push.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\split.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\status.py -> build\lib\pygest\cmdline
#   copying pygest\cmdline\__init__.py -> build\lib\pygest\cmdline
#   creating build\lib\pygest\rawdata
#   copying pygest\rawdata\glasser.py -> build\lib\pygest\rawdata
#   copying pygest\rawdata\miscellaneous.py -> build\lib\pygest\rawdata
#   copying pygest\rawdata\__init__.py -> build\lib\pygest\rawdata
#   copying pygest\rawdata\probes_fornito_15745.csv -> build\lib\pygest\rawdata
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\anas1\AppData\Local\Temp\pip-req-build-qp3e_4f1\setup.py", line 28, in <module>
#       setup(
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\site-packages\setuptools\command\build_py.py", line 55, in run
#       self.build_package_data()
#     File "C:\Users\anas1\AppData\Local\Programs\Python\Python39\lib\site-packages\setuptools\command\build_py.py", line 126, in build_package_data
#       srcfile in self.distribution.convert_2to3_doctests):
#   AttributeError: 'Distribution' object has no attribute 'convert_2to3_doctests'
#   ----------------------------------------
#   ERROR: Failed building wheel for pygest
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\anas1\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\anas1\\AppData\\Local\\Temp\\pip-req-build-qp3e_4f1\\setup.py'"'"'; __file__='"'"'C:\\Users\\anas1\\AppData\\Local\\Temp\\pip-req-build-qp3e_4f1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\anas1\AppData\Local\Temp\pip-record-ngvhw66w\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\anas1\AppData\Local\Programs\Python\Python39\Include\pygest'
#          cwd: C:\Users\anas1\AppData\Local\Temp\pip-req-build-qp3e_4f1\
#     Complete output (61 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib
#     creating build\lib\pygest
#     copying pygest\algorithms.py -> build\lib\pygest

# %%
financial_params
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
ac_params
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import numpy as np

import syntheticChrissAlmgren as sca
from ddpg_agent import Agent

from collections import deque

# Create simulation environment
env = sca.MarketEnvironment()

# Initialize Feed-forward DNNs for Actor and Critic models. 
agent1 = Agent(state_size=env.observation_space_dimension(), action_size=env.action_space_dimension(),random_seed = 1225)
agent2 = Agent(state_size=env.observation_space_dimension(), action_size=env.action_space_dimension(),random_seed = 108)
# Set the liquidation time
lqt = 60

# Set the number of trades
n_trades = 60

# Set trader's risk aversion
tr1 = 1e-6
tr2 = 1e-6

# Set the number of episodes to run the simulation
episodes = 1300
shortfall_list = []
shortfall_hist1 = np.array([])
shortfall_hist2 = np.array([])
shortfall_deque1 = deque(maxlen=100)
shortfall_deque2 = deque(maxlen=100)
for episode in range(episodes): 
    # Reset the enviroment
    cur_state = env.reset(seed = episode, liquid_time = lqt, num_trades = n_trades, lamb1 = tr1,lamb2 = tr2)

    # set the environment to make transactions
    env.start_transactions()

    for i in range(n_trades + 1):
      
        # Predict the best action for the current state. 
        cur_state1 = np.delete(cur_state,8)
        cur_state2 = np.delete(cur_state,7)
        #print(cur_state[5:])
        action1 = agent1.act(cur_state1, add_noise = True)
        action2 = agent2.act(cur_state2, add_noise = True)
        #print(action1,action2)
        # Action is performed and new state, reward, info are received. 
        new_state, reward1, reward2, done1, done2, info = env.step(action1,action2)
        
        # current state, action, reward, new state are stored in the experience replay
        new_state1 = np.delete(new_state,8)
        new_state2 = np.delete(new_state,7)
        agent1.step(cur_state1, action1, reward1, new_state1, done1)
        agent2.step(cur_state2, action2, reward2, new_state2, done2)
        # roll over new state
        cur_state = new_state

        if info.done1 and info.done2:
            shortfall_hist1 = np.append(shortfall_hist1, info.implementation_shortfall1)
            shortfall_deque1.append(info.implementation_shortfall1)
            
            shortfall_hist2 = np.append(shortfall_hist2, info.implementation_shortfall2)
            shortfall_deque2.append(info.implementation_shortfall2)
            break
        
    if (episode + 1) % 100 == 0: # print average shortfall over last 100 episodes
        print('\rEpisode [{}/{}]\tAverage Shortfall for Agent1: ${:,.2f}'.format(episode + 1, episodes, np.mean(shortfall_deque1)))        
        print('\rEpisode [{}/{}]\tAverage Shortfall for Agent2: ${:,.2f}'.format(episode + 1, episodes, np.mean(shortfall_deque2)))
        shortfall_list.append([np.mean(shortfall_deque1),np.mean(shortfall_deque2)])
print('\nAverage Implementation Shortfall for Agent1: ${:,.2f} \n'.format(np.mean(shortfall_hist1)))
print('\nAverage Implementation Shortfall for Agent2: ${:,.2f} \n'.format(np.mean(shortfall_hist2)))
# Out:
# Episode [100/1300]	Average Shortfall for Agent1: $1,172,575.47
# Episode [100/1300]	Average Shortfall for Agent2: $1,183,832.73
# Episode [200/1300]	Average Shortfall for Agent1: $1,281,148.59
# Episode [200/1300]	Average Shortfall for Agent2: $1,281,025.43
# Episode [300/1300]	Average Shortfall for Agent1: $1,281,250.00
# Episode [300/1300]	Average Shortfall for Agent2: $1,281,250.00
# Episode [400/1300]	Average Shortfall for Agent1: $1,281,250.00
# Episode [400/1300]	Average Shortfall for Agent2: $1,281,250.00
# Episode [500/1300]	Average Shortfall for Agent1: $1,281,250.00
# Episode [500/1300]	Average Shortfall for Agent2: $1,281,250.00
# Episode [600/1300]	Average Shortfall for Agent1: $1,281,250.00
# Episode [600/1300]	Average Shortfall for Agent2: $1,281,250.00
# Episode [700/1300]	Average Shortfall for Agent1: $1,227,339.91
# Episode [700/1300]	Average Shortfall for Agent2: $1,253,734.24
# Episode [800/1300]	Average Shortfall for Agent1: $415,623.02
# Episode [800/1300]	Average Shortfall for Agent2: $433,944.85
# Episode [900/1300]	Average Shortfall for Agent1: $314,968.49
# Episode [900/1300]	Average Shortfall for Agent2: $317,854.76
# Episode [1000/1300]	Average Shortfall for Agent1: $318,731.56
# Episode [1000/1300]	Average Shortfall for Agent2: $317,495.71
# Episode [1100/1300]	Average Shortfall for Agent1: $329,135.85
# Episode [1100/1300]	Average Shortfall for Agent2: $333,255.71
# Episode [1200/1300]	Average Shortfall for Agent1: $300,993.44
# Episode [1200/1300]	Average Shortfall for Agent2: $301,320.57
# Episode [1300/1300]	Average Shortfall for Agent1: $294,413.69
# Episode [1300/1300]	Average Shortfall for Agent2: $292,937.04
#
# Average Implementation Shortfall for Agent1: $829,225.39
#
#
# Average Implementation Shortfall for Agent2: $833,877.00

# %%
shortfall = np.array(shortfall_list)

# %%
np.save('1e-6_1e-6_cooporation_shorfall_list.npy',shortfall)

# %%
print(tr1,tr2)
cur_state = env.reset(seed = episode, liquid_time = lqt, num_trades = n_trades, lamb1 = tr1,lamb2 = tr2)

    # set the environment to make transactions
env.start_transactions()

trajectory = np.zeros([n_trades+1,2])
for i in range(n_trades + 1):
    trajectory[i] = cur_state[7:]
    
    print(cur_state[7:])
        # Predict the best action for the current state. 
    cur_state1 = np.delete(cur_state,8)
    cur_state2 = np.delete(cur_state,7)
        #print(cur_state[5:])
    action1 = agent1.act(cur_state1, add_noise = True)
    action2 = agent2.act(cur_state2, add_noise = True)
        #print(action1,action2)
        # Action is performed and new state, reward, info are received. 
    new_state, reward1, reward2, done1, done2, info = env.step(action1,action2)
        
        # current state, action, reward, new state are stored in the experience replay
    new_state1 = np.delete(new_state,8)
    new_state2 = np.delete(new_state,7)
    agent1.step(cur_state1, action1, reward1, new_state1, done1)
    agent2.step(cur_state2, action2, reward2, new_state2, done2)
        # roll over new state
    cur_state = new_state

    if info.done1 and info.done2:
        shortfall_hist1 = np.append(shortfall_hist1, info.implementation_shortfall1)
        shortfall_deque1.append(info.implementation_shortfall1)
            
        shortfall_hist2 = np.append(shortfall_hist2, info.implementation_shortfall2)
        shortfall_deque2.append(info.implementation_shortfall2)
        break
        
if (episode + 1) % 100 == 0: # print average shortfall over last 100 episodes
    print('\rEpisode [{}/{}]\tAverage Shortfall for Agent1: ${:,.2f}'.format(episode + 1, episodes, np.mean(shortfall_deque1)))        
    print('\rEpisode [{}/{}]\tAverage Shortfall for Agent2: ${:,.2f}'.format(episode + 1, episodes, np.mean(shortfall_deque2)))
# Out:
# 1e-06 1e-06
# [1. 1.]
# [0.761694 0.656324]
# [0.603648 0.454928]
# [0.44365  0.334226]
# [0.305346 0.25539 ]
# [0.20247  0.202642]
# [0.13316  0.148788]
# [0.09197 0.10399]
# [0.064072 0.074902]
# [0.044238 0.052522]
# [0.03257  0.036602]
# [0.02397  0.024466]
# [0.018556 0.01732 ]
# [0.013314 0.011942]
# [0.009696 0.008204]
# [0.006774 0.005622]
# [0.004728 0.003898]
# [0.003236 0.002704]
# [0.00228  0.001762]
# [0.00165 0.00114]
# [0.001234 0.000778]
# [0.000932 0.000566]
# [0.000674 0.000392]
# [0.000506 0.00029 ]
# [0.000376 0.000212]
# [0.000294 0.00015 ]
# [0.000224 0.000108]
# [1.66e-04 7.40e-05]
# [1.14e-04 5.40e-05]
# [8.2e-05 4.2e-05]
# [5.8e-05 3.4e-05]
# [4.0e-05 2.8e-05]
# [2.6e-05 2.2e-05]
# [1.8e-05 1.8e-05]
# [1.2e-05 1.4e-05]
# [8.e-06 1.e-05]
# [6.e-06 8.e-06]
# [4.e-06 6.e-06]
# [2.e-06 4.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# [2.e-06 2.e-06]
# Episode [1300/1300]	Average Shortfall for Agent1: $298,868.72
# Episode [1300/1300]	Average Shortfall for Agent2: $296,739.36

# %%
np.save('1e-6_1e-6_competition_trajectory_1500.npy',trajectory)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import utils

# We set the default figure size
plt.rcParams['figure.figsize'] = [17.0, 7.0]


# Set the number of days to sell all shares (i.e. the liquidation time)
l_time = 60

# Set the number of trades
n_trades = 60

# Set the trader's risk aversion
t_risk = 1e-6

# Plot the trading list and trading trajectory. If show_trl = True, the data frame containing the values of the
# trading list and trading trajectory is printed
utils.plot_trade_list(lq_time = l_time, nm_trades = n_trades, tr_risk = t_risk, show_trl = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-407db19f3a21> in <module>
#      20 # Plot the trading list and trading trajectory. If show_trl = True, the data frame containing the values of the
#      21 # trading list and trading trajectory is printed
# ---> 22 utils.plot_trade_list(lq_time = l_time, nm_trades = n_trades, tr_risk = t_risk, show_trl = True)
#
# ~/Kaggle/finance/utils.py in plot_trade_list(lq_time, nm_trades, tr_risk, show_trl)
#     313
#     314     # Reset the environment with the given parameters
# --> 315     env.reset(liquid_time = lq_time, num_trades = nm_trades, lamb = tr_risk)
#     316
#     317     # Get the trading list from the environment
#
# TypeError: reset() got an unexpected keyword argument 'lamb'
